# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\HP\OneDrive\Documents\students_data.csv')

# %%
df.head(5)
# Out:
#    student_id  math_score  science_score  english_score  attendance_rate  \
# 0           1          78             85             80               92
# 1           2          65             70             68               75
# 2           3          90             88             94               96
# 3           4          55             60             58               70
# 4           5          72             74             70               85
#
#    final_grade
# 0           82
# 1           69
# 2           92
# 3           61
# 4           73

# %%
df.describe()
# Out:
#        student_id  math_score  science_score  english_score  attendance_rate  \
# count    50.00000   50.000000      50.000000      50.000000        50.000000
# mean     25.50000   74.760000      76.900000      75.420000        84.360000
# std      14.57738   13.624048      12.135712      13.201871         9.921652
# min       1.00000   50.000000      55.000000      52.000000        65.000000
# 25%      13.25000   63.250000      66.250000      64.250000        76.000000
# 50%      25.50000   75.000000      77.000000      74.000000        85.000000
# 75%      37.75000   86.750000      87.750000      87.250000        93.500000
# max      50.00000   97.000000      96.000000      98.000000        99.000000
#
#        final_grade
# count    50.000000
# mean     76.460000
# std      12.424811
# min      56.000000
# 25%      66.000000
# 50%      76.000000
# 75%      86.750000
# max      96.000000

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.dropna()
# Out:
#     student_id  math_score  science_score  english_score  attendance_rate  \
# 0            1          78             85             80               92
# 1            2          65             70             68               75
# 2            3          90             88             94               96
# 3            4          55             60             58               70
# 4            5          72             74             70               85
# 5            6          88             92             90               98
# 6            7          60             65             62               80
# 7            8          84             86             82               90
# 8            9          50             55             52               65
# 9           10          95             93             97               99
# 10          11          68             72             70               78
# 11          12          82             80             85               88
# ...

# %%
df['avg_score'] = df[['math_score', 'science_score', 'english_score']].mean(axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['attendance_rate'], y=df['final_grade'])
plt.title("Attendance vs Final Grade")
plt.xlabel("Attendance Rate (%)")
plt.ylabel("Final Grade")
plt.show()
